# %% [markdown]
# <a href="https://colab.research.google.com/github/nielitropar/computer-vision/blob/main/3_Class_Classifier_MobileNetV2_Transfer_Learning_%C2%B7_TFLite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
princelv84_airplane_car_ship_path = kagglehub.dataset_download('princelv84/airplane-car-ship')

print('Data source import complete.')
# Out:
# Downloading to /root/.cache/kagglehub/datasets/princelv84/airplane-car-ship/1.archive...
# 100%|██████████| 333M/333M [00:03<00:00, 98.4MB/s]
# Extracting files...
# Data source import complete.

# %% [markdown]
# # 3-Class Image Classifier: Airplane / Automobile / Ship
# ### AIML with IIT Ropar  · MobileNetV2 Transfer Learning · TFLite Export
#
# **Fixes applied in this version:**
# 1. `drop_remainder=True` on dataset loaders — safe MixUp / epoch-end batches
# 2. Base model accessed by name (`get_layer(...)`) — not by fragile index
# 3. Full `classification_report` + confusion matrix for per-class diagnostics
# 4. INT8-aware TFLite export with `representative_dataset_gen`
# 5. Horizontal-only `RandomFlip` (vertical is unrealistic for this domain)
# 6. `CosineDecayRestarts` correctly passed to optimizer (not callbacks list)
# 7. Grad-CAM fixed to use the functional API correctly

# %% [markdown]
# ## 1 · Install Dependencies

# %%
# !pip install tensorflow scikit-learn opencv-python-headless pillow -q
print("Dependencies installed")
# Out:
# Dependencies installed

# %% [markdown]
# ## 2 · Imports & GPU Check

# %%
import os, shutil, random, zipfile
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
import matplotlib.pyplot as plt
import sklearn.metrics as skm

print(f"TensorFlow: {tf.__version__}")
gpus = tf.config.list_physical_devices('GPU')
print(f"GPU available: {len(gpus) > 0}  {gpus}")

# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
# Out:
# TensorFlow: 2.20.0
# GPU available: True  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 3 · Load Dataset
#
# Fetch  your `dataset` from kaggle.
#
# https://www.kaggle.com/datasets/princelv84/airplane-car-ship/data
#
# Expected structure inside the dataset directory:
# ```
# dataset/
#   test/   airplane/  automobile/  ship/
#   val/   airplane/  automobile/  ship/
#   train/  airplane/  automobile/  ship/
#
# ```

# %%
import os

source_dir = '/kaggle/input/datasets/princelv84/airplane-car-ship/dataset'

test_path  = os.path.join(source_dir, 'test')
val_path   = os.path.join(source_dir, 'val')
train_path = os.path.join(source_dir, 'train')

def safe_listdir(path):
    return sorted(os.listdir(path)) if os.path.exists(path) else f"[Missing] {path}"

print(f"\nDataset root   : {source_dir}")
print(f"Train folders  : {safe_listdir(train_path)}")
print(f"Val folders    : {safe_listdir(val_path)}")
print(f"Test folders   : {safe_listdir(test_path)}")
# Out:
# Dataset root   : /kaggle/input/datasets/princelv84/airplane-car-ship/dataset
# Train folders  : [Missing] /kaggle/input/datasets/princelv84/airplane-car-ship/dataset/train
# Val folders    : [Missing] /kaggle/input/datasets/princelv84/airplane-car-ship/dataset/val
# Test folders   : [Missing] /kaggle/input/datasets/princelv84/airplane-car-ship/dataset/test

# %% [markdown]
# ## 4 · tf.data Pipelines
#
# **Fix:** `drop_remainder=True` prevents unequal-length batches at epoch end, which could cause silent shape mismatches when MixUp is used.

# %%
IMG_SIZE = 128
BATCH    = 32
AUTOTUNE = tf.data.AUTOTUNE

# Correcting source_dir for Colab environment
import os
source_dir = os.path.join(princelv84_airplane_car_ship_path, 'dataset')

# Step 1: Load datasets (NO batching here)
train_ds_raw = tf.keras.utils.image_dataset_from_directory(
    os.path.join(source_dir, 'train'), # Changed from FINAL_DIR
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=None,
    shuffle=True,
    seed=SEED,
)

val_ds_raw = tf.keras.utils.image_dataset_from_directory(
    os.path.join(source_dir, 'val'),
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=None,
    shuffle=False,
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    os.path.join(source_dir, 'test'),
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH,
    shuffle=False,
)

# Class info
class_names = train_ds_raw.class_names
NUM_CLASSES = len(class_names)
print("Classes:", class_names)

# Step 2: Apply batching manually (IMPORTANT)
train_ds_raw = train_ds_raw.batch(BATCH, drop_remainder=True)
val_ds = val_ds_raw.batch(BATCH, drop_remainder=True)

# Augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.15),
    layers.RandomZoom(0.15),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomContrast(0.2),
], name="augmentation")

# Step 3: Apply augmentation + prefetch
train_ds = (
    train_ds_raw
    .map(lambda x, y: (data_augmentation(x, training=True), y),
         num_parallel_calls=AUTOTUNE)
    .prefetch(AUTOTUNE)
)

val_ds = val_ds.prefetch(AUTOTUNE)
test_ds = test_ds.prefetch(AUTOTUNE)

print("\nPipelines ready")
# Out:
# Found 2400 files belonging to 3 classes.
# Found 600 files belonging to 3 classes.
# Found 582 files belonging to 3 classes.
# Classes: ['airplane', 'automobile', 'ship']
#
# Pipelines ready

# %% [markdown]
# ### 4a · Visualise Augmented Samples

# %%
plt.figure(figsize=(14, 4))
for images, labels in train_ds.take(1):
    for i in range(min(8, len(images))):
        ax = plt.subplot(2, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]], fontsize=9)
        plt.axis("off")
plt.suptitle("Augmented Training Samples", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## · Concept Check: Why do we freeze the backbone?
# When we add a new, randomly initialized dense layer (the "classification head") to our pre-trained MobileNetV2, it initially makes completely random predictions.
#
# If we were to train the entire network right away, the gradients calculated from these massive initial errors would be huge. These massive error signals would propagate backward through the network and **destroy** the carefully learned, delicate features already present in the MobileNetV2 backbone.
#
# **The Strategy:**
# 1. **Phase 1 (Feature Extraction):** Freeze the backbone. Train *only* the new head so it learns to make basic sense of the features MobileNetV2 is already extracting.
# 2. **Phase 2 (Fine-Tuning):** Unfreeze the backbone (or just the top layers). Train the *entire* network with a very small learning rate to gently adapt the pre-trained features specifically to airplanes, cars, and ships without wrecking the foundational weights.

# %% [markdown]
# ## 5 · Phase 1 — Feature Extraction (Frozen MobileNetV2)
#
# Train only the new classification head with the backbone frozen.
# This warms up the head weights before fine-tuning.

# %%
BASE_NAME = f"mobilenetv2_1.00_{IMG_SIZE}"   # exact layer name used later

# Build model
base = tf.keras.applications.MobileNetV2(
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False,
    weights="imagenet"
)
base.trainable = False

inputs  = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x       = layers.Rescaling(1.0 / 255)(inputs)
x       = base(x, training=False)
x       = layers.GlobalAveragePooling2D()(x)
x       = layers.Dense(256, activation="relu")(x)
x       = layers.BatchNormalization()(x)
x       = layers.Dropout(0.4)(x)
x       = layers.Dense(128, activation="relu")(x)
x       = layers.Dropout(0.3)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = models.Model(inputs, outputs, name="MobileNetV2_Classifier")
model.summary(expand_nested=False)

model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "MobileNetV2_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_128            │ (None, 4, 4, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,620,227 (10.00 MB)
#  Trainable params: 361,731 (1.38 MB)
#  Non-trainable params: 2,258,496 (8.62 MB)

# %%
cb1 = [
    callbacks.EarlyStopping(monitor="val_accuracy", patience=5,
                            restore_best_weights=True, verbose=1),
    callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5,
                                patience=3, min_lr=1e-6, verbose=1),
    callbacks.ModelCheckpoint("best_phase1.keras", monitor="val_accuracy",
                               save_best_only=True, verbose=1),
]

print("=" * 50)
print("PHASE 1 — Feature Extraction")
print("=" * 50)
history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15,
    callbacks=cb1,
    verbose=1,
)
# Out:
# ==================================================
# PHASE 1 — Feature Extraction
# ==================================================
# Epoch 1/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.8242 - loss: 0.4696
# Epoch 1: val_accuracy improved from None to 0.98785, saving model to best_phase1.keras
#
# Epoch 1: finished saving model to best_phase1.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 57s 485ms/step - accuracy: 0.9033 - loss: 0.2730 - val_accuracy: 0.9878 - val_loss: 0.0450 - learning_rate: 0.0010
# Epoch 2/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9420 - loss: 0.1717
# Epoch 2: val_accuracy improved from 0.98785 to 0.99479, saving model to best_phase1.keras
#
# Epoch 2: finished saving model to best_phase1.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 278ms/step - accuracy: 0.9475 - loss: 0.1563 - val_accuracy: 0.9948 - val_loss: 0.0176 - learning_rate: 0.0010
# Epoch 3/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9617 - loss: 0.1103
# Epoch 3: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 297ms/step - accuracy: 0.9625 - loss: 0.1068 - val_accuracy: 0.9913 - val_loss: 0.0367 - learning_rate: 0.0010
# Epoch 4/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9587 - loss: 0.1153
# Epoch 4: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 24s 299ms/step - accuracy: 0.9575 - loss: 0.1145 - val_accuracy: 0.9931 - val_loss: 0.0324 - learning_rate: 0.0010
# Epoch 5/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9655 - loss: 0.1036
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 5: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 23s 300ms/step - accuracy: 0.9650 - loss: 0.1065 - val_accuracy: 0.9931 - val_loss: 0.0315 - learning_rate: 0.0010
# Epoch 6/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9659 - loss: 0.0963
# Epoch 6: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 37s 245ms/step - accuracy: 0.9629 - loss: 0.1064 - val_accuracy: 0.9931 - val_loss: 0.0200 - learning_rate: 5.0000e-04
# Epoch 7/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9648 - loss: 0.0936
# Epoch 7: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 347ms/step - accuracy: 0.9683 - loss: 0.0907 - val_accuracy: 0.9931 - val_loss: 0.0205 - learning_rate: 5.0000e-04
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.

# %% [markdown]
# ## 6 · Phase 2 — Fine-Tuning (Unfreeze Top 30 Layers)
#
# **Fix:** Base model accessed by name via `get_layer(BASE_NAME)` — not by fragile positional index.
# **Fix:** `CosineDecayRestarts` is a LR *schedule*, passed directly to the optimizer — not listed in callbacks.

# %%
# Load best phase-1 checkpoint
model = tf.keras.models.load_model("best_phase1.keras")

# access base by name, not by index
base_layer = model.get_layer(BASE_NAME)
base_layer.trainable = True

UNFREEZE_FROM = len(base_layer.layers) - 30
for layer in base_layer.layers[:UNFREEZE_FROM]:
    layer.trainable = False

trainable_n = sum(1 for l in base_layer.layers if l.trainable)
print(f"Trainable base layers : {trainable_n} / {len(base_layer.layers)}")
total_params = model.count_params()
print(f"Total trainable params: {sum(p.numpy().size for p in model.trainable_variables):,}")

# CosineDecayRestarts goes INTO the optimizer, not callbacks
cosine_lr = tf.keras.optimizers.schedules.CosineDecayRestarts(
    initial_learning_rate=1e-5,
    first_decay_steps=5,
    t_mul=2.0,
    m_mul=0.8,
)

model.compile(
    optimizer=optimizers.Adam(learning_rate=cosine_lr),   # ← FIX 4
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
print("Model recompiled")
# Out:
# Trainable base layers : 30 / 154
# Total trainable params: 1,888,131
# Model recompiled

# %%
cb2 = [
    callbacks.EarlyStopping(monitor="val_accuracy", patience=7,
                            restore_best_weights=True, verbose=1),
    callbacks.ModelCheckpoint("best_finetuned.keras", monitor="val_accuracy",
                               save_best_only=True, verbose=1),
    # No ReduceLROnPlateau — cosine schedule is already in the optimizer
]

print("=" * 50)
print("PHASE 2 — Fine-Tuning")
print("=" * 50)
history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=cb2,
    verbose=1,
)
# Out:
# ==================================================
# PHASE 2 — Fine-Tuning
# ==================================================
# Epoch 1/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9018 - loss: 0.2757
# Epoch 1: val_accuracy improved from None to 0.99479, saving model to best_finetuned.keras
#
# Epoch 1: finished saving model to best_finetuned.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 54s 421ms/step - accuracy: 0.8992 - loss: 0.2847 - val_accuracy: 0.9948 - val_loss: 0.0191
# Epoch 2/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9047 - loss: 0.2345
# Epoch 2: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 348ms/step - accuracy: 0.9083 - loss: 0.2375 - val_accuracy: 0.9948 - val_loss: 0.0210
# Epoch 3/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9110 - loss: 0.2595
# Epoch 3: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 19s 249ms/step - accuracy: 0.9208 - loss: 0.2258 - val_accuracy: 0.9948 - val_loss: 0.0223
# Epoch 4/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9267 - loss: 0.2405
# Epoch 4: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 259ms/step - accuracy: 0.9204 - loss: 0.2349 - val_accuracy: 0.9931 - val_loss: 0.0233
# Epoch 5/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.9167 - loss: 0.2246
# Epoch 5: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 19s 257ms/step - accuracy: 0.9200 - loss: 0.2132 - val_accuracy: 0.9931 - val_loss: 0.0239
# Epoch 6/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9319 - loss: 0.1783
# Epoch 6: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - accuracy: 0.9271 - loss: 0.2091 - val_accuracy: 0.9913 - val_loss: 0.0248
# Epoch 7/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9262 - loss: 0.1953
# Epoch 7: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 295ms/step - accuracy: 0.9329 - loss: 0.1786 - val_accuracy: 0.9913 - val_loss: 0.0255
# Epoch 8/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9254 - loss: 0.2072
# Epoch 8: val_accuracy did not improve from 0.99479
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 20s 268ms/step - accuracy: 0.9342 - loss: 0.1929 - val_accuracy: 0.9913 - val_loss: 0.0263
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
def plot_finetuning_history(history_phase1, history_phase2, initial_epochs):
    """Combines and plots the history of Phase 1 and Phase 2."""
    acc = history_phase1.history['accuracy'] + history_phase2.history['accuracy']
    val_acc = history_phase1.history['val_accuracy'] + history_phase2.history['val_accuracy']

    loss = history_phase1.history['loss'] + history_phase2.history['loss']
    val_loss = history_phase1.history['val_loss'] + history_phase2.history['val_loss']

    plt.figure(figsize=(16, 5))

    # Accuracy Plot
    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy', color='blue')
    plt.plot(val_acc, label='Validation Accuracy', color='orange')
    plt.axvline(x=initial_epochs-1, color='red', linestyle='--', label='Unfreeze Point')
    plt.title('Training and Validation Accuracy', fontsize=12)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)

    # Loss Plot
    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss', color='blue')
    plt.plot(val_loss, label='Validation Loss', color='orange')
    plt.axvline(x=initial_epochs-1, color='red', linestyle='--', label='Unfreeze Point')
    plt.title('Training and Validation Loss', fontsize=12)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.suptitle("Phase 1 (Feature Extraction) vs Phase 2 (Fine-Tuning)", fontsize=14, weight='bold')
    plt.tight_layout()
    plt.show()

plot_finetuning_history(history1, history2, initial_epochs=15)

# %% [markdown]
# ## 7 · Training Curves

# %%
def plot_history(h1, h2):
    acc   = h1.history["accuracy"]     + h2.history["accuracy"]
    vacc  = h1.history["val_accuracy"] + h2.history["val_accuracy"]
    loss  = h1.history["loss"]         + h2.history["loss"]
    vloss = h1.history["val_loss"]     + h2.history["val_loss"]
    ph1   = len(h1.history["accuracy"])

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for ax, tr, val, title in zip(axes,
                                   [acc, loss], [vacc, vloss],
                                   ["Accuracy", "Loss"]):
        ax.plot(tr,  label=f"Train {title}")
        ax.plot(val, label=f"Val {title}")
        ax.axvline(ph1 - 1, color="gray", linestyle="--",
                   label="Fine-tuning start", alpha=0.7)
        ax.set_title(title, fontsize=12)
        ax.set_xlabel("Epoch")
        ax.legend()
        ax.grid(alpha=0.3)
    plt.suptitle("Phase 1 (Feature Extraction) → Phase 2 (Fine-Tuning)", fontsize=13)
    plt.tight_layout()
    plt.savefig("training_curves.png", dpi=150)
    plt.show()
    print("Saved training_curves.png")

plot_history(history1, history2)
# Out:
# Saved training_curves.png

# %% [markdown]
# ## 8 · Full Evaluation
#
# **Fix:** Added `classification_report` and confusion matrix for per-class precision / recall.
# Evaluates on both **val** (to match training monitoring) and the truly held-out **test** set.

# %%
best_model = tf.keras.models.load_model("best_finetuned.keras")

# Aggregate metrics
val_loss,  val_acc  = best_model.evaluate(val_ds,  verbose=0)
test_loss, test_acc = best_model.evaluate(test_ds, verbose=0)

print(f"{'─'*45}")
print(f"  Val  Accuracy : {val_acc*100:6.2f}%   Loss: {val_loss:.4f}")
print(f"  Test Accuracy : {test_acc*100:6.2f}%   Loss: {test_loss:.4f}  ← unbiased")
print(f"{'─'*45}")
# Out:
# ─────────────────────────────────────────────
#   Val  Accuracy :  99.48%   Loss: 0.0191
#   Test Accuracy :  99.66%   Loss: 0.0068  ← unbiased
# ─────────────────────────────────────────────

# %%
# Per-class classification report
def evaluate_detailed(ds, split_name):
    y_true, y_pred = [], []
    for images, labels in ds:
        preds = best_model.predict(images, verbose=0)
        y_true.extend(labels.numpy())
        y_pred.extend(np.argmax(preds, axis=1))

    print(f"\n{'='*50}")
    print(f"  Classification Report — {split_name}")
    print(f"{'='*50}")
    print(skm.classification_report(y_true, y_pred, target_names=class_names, digits=3))
    return y_true, y_pred

# Validate on both splits
y_true_val, y_pred_val   = evaluate_detailed(val_ds,  "Validation Set")
y_true_test, y_pred_test = evaluate_detailed(test_ds, "Test Set (held-out)")
# Out:
# ==================================================
#   Classification Report — Validation Set
# ==================================================
#               precision    recall  f1-score   support
#
#     airplane      1.000     0.985     0.992       200
#   automobile      0.990     1.000     0.995       200
#         ship      0.994     1.000     0.997       176
#
#     accuracy                          0.995       576
#    macro avg      0.995     0.995     0.995       576
# weighted avg      0.995     0.995     0.995       576
#
#
# ==================================================
#   Classification Report — Test Set (held-out)
# ==================================================
#               precision    recall  f1-score   support
#
#     airplane      0.995     0.995     0.995       189
#   automobile      0.995     1.000     0.997       193
#         ship      1.000     0.995     0.997       200
#
#     accuracy                          0.997       582
#    macro avg      0.997     0.997     0.997       582
# weighted avg      0.997     0.997     0.997       582

# %%
# Confusion matrices
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

for ax, y_true, y_pred, title in zip(
    axes,
    [y_true_val, y_true_test],
    [y_pred_val, y_pred_test],
    ["Confusion Matrix — Val", "Confusion Matrix — Test (held-out)"]
):
    cm   = skm.confusion_matrix(y_true, y_pred)
    disp = skm.ConfusionMatrixDisplay(cm, display_labels=class_names)
    disp.plot(ax=ax, colorbar=False, cmap="Blues")
    ax.set_title(title, fontsize=11)

plt.tight_layout()
plt.savefig("confusion_matrices.png", dpi=150)
plt.show()
print("Saved confusion_matrices.png")
# Out:
# Saved confusion_matrices.png

# %% [markdown]
# ## 9 · Visualise Misclassified Samples

# %%
MAX_SHOW = 12
wrong_imgs, wrong_true, wrong_pred = [], [], []

for images, labels in val_ds:
    preds = best_model.predict(images, verbose=0)
    for img, true, prob in zip(images.numpy(), labels.numpy(), preds):
        p = np.argmax(prob)
        if p != true:
            wrong_imgs.append(img.astype("uint8"))
            wrong_true.append(true)
            wrong_pred.append(p)
        if len(wrong_imgs) >= MAX_SHOW:
            break
    if len(wrong_imgs) >= MAX_SHOW:
        break

if wrong_imgs:
    cols = 4
    rows = (len(wrong_imgs) + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(14, rows * 3.5))
    axes = axes.flatten()
    for ax, img, t, p in zip(axes, wrong_imgs, wrong_true, wrong_pred):
        ax.imshow(img)
        ax.set_title(f"True: {class_names[t]}\nPred: {class_names[p]}", fontsize=8,
                     color="red")
        ax.axis("off")
    for ax in axes[len(wrong_imgs):]:
        ax.axis("off")
    plt.suptitle("Misclassified Samples (Val Set)", fontsize=12)
    plt.tight_layout()
    plt.show()
else:
    print("No misclassified images found in the validation set!")

# %% [markdown]
# ## 10 · Grad-CAM Visualisation
#
# Shows which image regions drove the model's prediction.
# **Fix:** Uses the functional API correctly — gradients taken w.r.t. the last conv feature map.

# %% [markdown]
# ### Model Interpretability: Grad-CAM
# Deep learning models are often treated as "black boxes." Gradient-weighted Class Activation Mapping (Grad-CAM) helps us peer inside by using the gradients of the target concept to produce a coarse localization map. This heatmap highlights the regions in the image that were most important for predicting the concept.

# %%
# 1. GRAD-CAM FUNCTION
def make_gradcam_heatmap(img_array, model, base_model_name, last_conv_layer_name):
    # Extract the nested base model
    base_model = model.get_layer(base_model_name)

    # Create a sub-model strictly for the inner base_model.
    # EXPLICITLY using `inputs=` and `outputs=` fixes the "too many positional arguments" error!
    grad_model = tf.keras.models.Model(
        inputs=base_model.inputs,
        outputs=[base_model.get_layer(last_conv_layer_name).output, base_model.output]
    )

    # Identify layers before and after the base_model (Augmentations, Dense heads, etc.)
    layers_before = []
    layers_after = []
    passed_base = False

    for layer in model.layers:
        if layer.name == base_model_name:
            passed_base = True
            continue

        # Skip InputLayers to avoid invocation errors
        if isinstance(layer, tf.keras.layers.InputLayer):
            continue

        if not passed_base:
            layers_before.append(layer)
        else:
            layers_after.append(layer)

    with tf.GradientTape() as tape:
        # Forward pass: Layers BEFORE base model (e.g., Augmentation)
        x = img_array
        for layer in layers_before:
            x = layer(x)

        # Forward pass: Base model
        conv_out, base_out = grad_model(x)

        # Explicitly tell the tape to track the inner convolutional output
        tape.watch(conv_out)

        # Forward pass: Layers AFTER base model (e.g., GAP, Dropout, Dense)
        preds = base_out
        for layer in layers_after:
            preds = layer(preds)

        # Get highest predicted class
        pred_idx = tf.argmax(preds[0])
        class_channel = preds[:, pred_idx]

    # Calculate gradients
    grads = tape.gradient(class_channel, conv_out)
    pooled = tf.reduce_mean(grads, axis=(0, 1, 2))

    # Generate heatmap
    heatmap = conv_out[0] @ pooled[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap).numpy()
    heatmap = np.maximum(heatmap, 0)

    if heatmap.max() > 0:
        heatmap /= heatmap.max()

    return heatmap, class_names[pred_idx.numpy()]


# 2. OVERLAY FUNCTION
def overlay_gradcam(orig_img, heatmap, alpha=0.45):
    import cv2
    h, w = orig_img.shape[:2]
    heatmap_resized = cv2.resize(heatmap, (w, h))
    heatmap_colored = cv2.applyColorMap(
        np.uint8(255 * heatmap_resized), cv2.COLORMAP_JET)
    heatmap_colored = cv2.cvtColor(heatmap_colored, cv2.COLOR_BGR2RGB)
    overlay = (heatmap_colored * alpha + orig_img * (1 - alpha)).astype(np.uint8)
    return overlay


# 3. PLOTTING LOOP
BASE_NAME = "mobilenetv2_1.00_128" # Check model.summary() to ensure this matches exactly!
LAST_CONV = "out_relu"             # last activation in MobileNetV2

fig, axes = plt.subplots(3, 4, figsize=(16, 9))
sample_idx = 0

for images, labels in val_ds.take(3):
    for i in range(min(4, len(images))):
        img_np = images[i].numpy().astype("uint8")
        inp    = np.expand_dims(images[i].numpy().astype(np.float32), 0)

        try:
            # Calling the 4-argument function properly
            heatmap, pred_cls = make_gradcam_heatmap(inp, best_model, BASE_NAME, LAST_CONV)
            overlay = overlay_gradcam(img_np, heatmap)
            axes[sample_idx // 4, sample_idx % 4].imshow(overlay)
        except Exception as e:
            # Print the error so you can see exactly why it failed if it happens again
            print(f"Error processing image {sample_idx}: {e}")
            axes[sample_idx // 4, sample_idx % 4].imshow(img_np)
            pred_cls = "err"

        true_cls = class_names[labels[i].numpy()]
        axes[sample_idx // 4, sample_idx % 4].set_title(
            f"True: {true_cls}\nPred: {pred_cls}",
            fontsize=8,
            color="green" if pred_cls == true_cls else "red"
        )
        axes[sample_idx // 4, sample_idx % 4].axis("off")

        sample_idx += 1
        if sample_idx >= 12:
            break

    if sample_idx >= 12:
        break

plt.suptitle("Grad-CAM — Attention Maps (green title = correct, red = wrong)", fontsize=11)
plt.tight_layout()
plt.savefig("gradcam.png", dpi=150)
plt.show()

# %% [markdown]
# ## 11 · TFLite Export - Full INT8 Quantization
#
# **Fix:** Provides a `representative_dataset_gen` for proper INT8 quantization (better accuracy-size tradeoff than dynamic-range-only).
# Input/output kept as `float32` for easy deployment flexibility.

# %%
# representative dataset for INT8 calibration
def representative_data_gen():
    """Yields 50 calibration batches — used only for INT8 scale/zero-point estimation."""
    for images, _ in val_ds.take(50):
        yield [tf.cast(images, tf.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
converter.optimizations               = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset      = representative_data_gen
converter.target_spec.supported_ops   = [
    tf.lite.OpsSet.TFLITE_BUILTINS_INT8,
    tf.lite.OpsSet.TFLITE_BUILTINS,    # fallback for unsupported ops
]
converter.inference_input_type  = tf.float32   # keep float I/O for flexibility
converter.inference_output_type = tf.float32

tflite_model = converter.convert()

tflite_path = "model_int8.tflite"
with open(tflite_path, "wb") as f:
    f.write(tflite_model)

size_mb = len(tflite_model) / 1e6
print(f"TFLite model saved  →  {tflite_path}  ({size_mb:.2f} MB)")
# Out:
# Saved artifact at '/tmp/tmp1lho29_6'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   140623823860560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823861904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823861712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823861328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823862480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823861136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823862864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823862096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823862672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823863440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823861520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823859792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823863248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823863056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823862288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823860752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646410128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646410320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623823863632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646409168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646408784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646409936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646409744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646409552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646411280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646410704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646410896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646411088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646408976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646412240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646411664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646411856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646412048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646409360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646413200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646412624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646412816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646413008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646410512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646414160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646413584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646413776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646413968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646411472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646415120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646414544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646414736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646414928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646412432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646416080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646415504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646415696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646415888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646413392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646417040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646416464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646416656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646416848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646414352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646418000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646417424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646417616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646417808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646415312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646418960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646418384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646418576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646418768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646416272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646419920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646419344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646419536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646419728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646417232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646420880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140626737112720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646420496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646420688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646419152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646421840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646421264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646421456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646421648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646421072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646422800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646422224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646422416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646422608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646420112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646423760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646423184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646423376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646423568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646420304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646424720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646424144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646422992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646424528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646424336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646423952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646422032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645197712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645197904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623646424912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645196752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645196368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645197520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645197328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645197136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645198864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645198288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645198480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645198672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645196560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645199824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645199248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645199440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645199632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645196944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645200784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645200208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645200400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645200592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645198096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645201744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645201168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645201360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645201552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645199056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645202704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645202128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645202320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645202512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645200016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645203664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645203088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645203280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645203472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645200976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645204624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645204048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645204240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645204432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645201936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645205584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645205008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645205200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645205392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645202896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645206544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645205968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645206160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645206352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645203856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645207504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645206928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645207120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645207312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645204816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645208464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645207888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645208080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645208272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645205776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645209424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645208848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645209040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645209232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645206736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645210384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645209808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645210000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645210192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645207696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645211344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645210768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645210960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645211152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645208656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645212304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645211728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645210576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645212112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645211920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645211536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645209616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643952528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643952720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623645212496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643951568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643951184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643952336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643952144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643951952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643953680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643953104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643953296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643953488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643951376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643954640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643954064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643954256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643954448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643951760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643955600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643955024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643955216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643955408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643952912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643956560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643955984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643956176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643956368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643953872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643957520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643956944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643957136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643957328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643954832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643958480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643957904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643958096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643958288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643955792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643959440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643958864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643959056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643959248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643956752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643960400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643959824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643960016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643960208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643957712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643961360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643960784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643960976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643961168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643958672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643962320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643961744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643961936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643962128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643959632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643963280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643962704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643962896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643963088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643960592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643964240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643963664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643963856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643964048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643961552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643965200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643964624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643964816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643965008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643962512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643966160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643964432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643963472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643965968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643966928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643967120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643965776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643966352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623643966544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623642870032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140623642870608: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:863: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# TFLite model saved  →  model_int8.tflite  (3.08 MB)

# %%
# Sanity-check TFLite inference
interpreter = tf.lite.Interpreter(model_path=tflite_path)
interpreter.allocate_tensors()
inp_idx = interpreter.get_input_details()[0]["index"]
out_idx = interpreter.get_output_details()[0]["index"]

correct, total = 0, 0
for images, labels in val_ds.take(10):
    for img, label in zip(images.numpy(), labels.numpy()):
        inp = np.expand_dims(img.astype(np.float32), 0)
        interpreter.set_tensor(inp_idx, inp)
        interpreter.invoke()
        pred = np.argmax(interpreter.get_tensor(out_idx))
        correct += int(pred == label)
        total   += 1

print(f"TFLite sanity-check accuracy: {correct/total*100:.1f}%  on {total} samples")
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# TFLite sanity-check accuracy: 98.8%  on 320 samples

# %% [markdown]
# ## 12 · Single-Image Inference
#
# Upload any image and get the model's prediction with confidence scores.

# %%
import numpy as np
import cv2
import requests
import matplotlib.pyplot as plt

IMG_SIZE = 224  # ensure this matches your training config

url = "https://raw.githubusercontent.com/nielitropar/computer-vision/refs/heads/main/assets/testcar.png"

# Fetch image
resp = requests.get(url, timeout=10)
resp.raise_for_status()

img_array = np.frombuffer(resp.content, np.uint8)
img_bgr = cv2.imdecode(img_array, cv2.IMREAD_COLOR)

if img_bgr is None:
    raise ValueError("Failed to decode image from URL")

# Preprocess
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
img_resized = cv2.resize(img_rgb, (IMG_SIZE, IMG_SIZE))

inp = np.expand_dims(img_resized.astype(np.float32), 0)  # (1, H, W, 3)

# IMPORTANT: match training preprocessing
# If you used normalization like /255 during training, add:
# inp = inp / 255.0

# Inference
probs = best_model.predict(inp, verbose=0)[0]
pred_idx  = np.argmax(probs)
pred_name = class_names[pred_idx]

# Visualization
plt.figure(figsize=(5, 5))
plt.imshow(img_rgb)
plt.title(f"Predicted: {pred_name}  ({probs[pred_idx]*100:.1f}%)", fontsize=13)
plt.axis("off")
plt.tight_layout()
plt.show()

# Probabilities
print("\nAll class probabilities:")
for name, p in sorted(zip(class_names, probs), key=lambda x: -x[1]):
    bar = "█" * int(p * 40)
    print(f"{name:12s}: {p*100:6.2f}%  {bar}")
# Out:
# All class probabilities:
# automobile  :  65.02%  ██████████████████████████
# airplane    :  32.26%  ████████████
# ship        :   2.72%  █

# %% [markdown]
# ## 13 · Save & Download All Outputs

# %%
import os
import shutil

OUTPUT_DIR = "/kaggle/working/exports"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Save TFLite model
if os.path.exists("model_int8.tflite"):
    shutil.copy("model_int8.tflite", f"{OUTPUT_DIR}/model_int8.tflite")
    print("model_int8.tflite saved")

# Save training artifacts
artifact_files = [
    "training_curves.png",
    "confusion_matrices.png",
    "gradcam.png"
]

for fname in artifact_files:
    if os.path.exists(fname):
        shutil.copy(fname, f"{OUTPUT_DIR}/{fname}")
        print(f" {fname} saved")

# Save Keras model
best_model.save(f"{OUTPUT_DIR}/best_model_final.keras")
print("best_model_final.keras saved")

# Optional: Zip everything for easy download
zip_path = "/kaggle/working/model_artifacts.zip"
shutil.make_archive(zip_path.replace(".zip", ""), 'zip', OUTPUT_DIR)

print(f"\n All files packaged at: {zip_path}")
# Out:
# model_int8.tflite saved
#  training_curves.png saved
#  confusion_matrices.png saved
#  gradcam.png saved
# best_model_final.keras saved
#
#  All files packaged at: /kaggle/working/model_artifacts.zip

# %% [markdown]
# # **Live Demo:**

# %% [markdown]
# https://nielitropar-airplane-car-ship-classifier.hf.space
